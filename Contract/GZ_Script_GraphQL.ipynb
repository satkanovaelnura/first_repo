# %%
import requests
import json
import pandas as pd
import time 

hernya = 

df_12 = pd.DataFrame()

def send_graphql_request(customer_bin, after=None):
    url = "https://ows.goszakup.gov.kz/v3/graphql/query"
    headers = {
        "Authorization": "Bearer 36e52c17fd04fd3ebd3222319c4f289b",
        "Content-Type": "application/json"
    }

    # Создаем фильтр с параметром "customerBin" и опциональным "after"
    filter_params = f'{{customerBin: "{customer_bin}", finYear: 2023}}'
    if after:
        filter_params += f', after: {after}'


    # Запрос GraphQL
    graphql_query = {
        "query": f'query Test123456789 {{Contract(limit: 200, filter: {filter_params}) {{contractNumberSys Supplier{{nameRu}} descriptionRu FaktTradeMethods{{nameRu}} faktSum contractSumWnds RefSubjectType{{nameRu}} }}}}'
    }

    try:
        response = requests.post(url, headers=headers, json=graphql_query, verify=False)
        response.raise_for_status()
        data = response.json()

        # Проверяем наличие "hasNextPage" и значение "lastId"
        page_info = data.get("extensions", {}).get("pageInfo", {})
        has_next_page = page_info.get("hasNextPage", False)
        last_id = page_info.get("lastId")

        return data, has_next_page, last_id
    except requests.exceptions.RequestException as e:
        print(f"Ошибка при выполнении запроса для {customer_bin}: {e}")
        return None, False, None

# Ваш список данных
customer_bin_list = [hernya]

current_name = f'Contract_{hernya}.csv'

# Переменная для отслеживания "lastId"
last_id = None

# Создайте пустой список для хранения данных
data_list = []

# Повторяем запросы для каждого значения в списке
for customer_bin in customer_bin_list:
    has_next_page = True
    while has_next_page:
        result, has_next_page, last_id = send_graphql_request(customer_bin, after=last_id)
        time.sleep(1) # Добавьте задержку в несколько секунд перед следующим запросом
        if result is not None:
            print(f"Результат запроса для {customer_bin}:")
            print(json.dumps(result, indent=2))

            # Извлеките интересующие вас данные из JSON-ответа
            data = result.get("data", {})
            contracts = data.get("Contract", [])

            if contracts is not None:
                # Преобразуйте данные в DataFrame
                new_df = pd.DataFrame(contracts)

                # Добавьте новые записи в существующий DataFrame
                #df_12 = df_12.append(new_df, ignore_index=True)
                df_12 = pd.concat([df_12, new_df])
                print(df_12)
print("END")

df_12.to_csv({current_name}, index=False, sep = ';')
# Out:
#   Cell In[7], line 6
#     hernya =
#              ^
# SyntaxError: invalid syntax

# %%
import certifi
import urllib3
http = urllib3.PoolManager(
    cert_reqs='CERT_REQUIRED',
    ca_certs=certifi.where()
)

# %%
import urllib3
urllib3.disable_warnings()

# %%
import requests

url = 'https://ows.goszakup.gov.kz'
response = requests.get(url, verify=False)
print(response.text)
# Out:
# <!DOCTYPE html>
# <html lang="en">
#   <head>
#     <title>Унифицированные сервисы</title>
#     <meta charset="utf-8" />
#     <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1" />
#     <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0">
#     <link rel="stylesheet" href="//cdnjs.cloudflare.com/ajax/libs/semantic-ui/2.2.4/semantic.min.css">
#     <link rel="stylesheet" href="//cdnjs.cloudflare.com/ajax/libs/prism/1.5.1/themes/prism-okaidia.min.css" />
#     <style>
#       blockquote {
#         border-left: solid 4px #eee;
#         padding-left: 8px;
#         font-style: italic;
#         margin-left: 0;
#         padding: 8px;
#       }
#
#       .ui.micro.label {
#         font-size: .25rem;
#       }
#
#       .ui.transaction.accordion .title {
#         text-align: center;
#       }
#
#       .ui.transaction.accordion .content {
#         border-top: solid 1px #ddd !important;
# ...
